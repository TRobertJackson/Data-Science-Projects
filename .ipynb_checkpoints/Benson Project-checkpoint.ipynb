# %% [markdown]
# # Benson Project
#
# WomenTechWomenYes (WTWY) has an annual gala at the beginning of the summer each year. There has been a significant drop in attendance at the last WTWY Gala. This will affect the direction and efficacy of WTWY’s mission statement - that is unacceptable.
#
# We recently obtained NYC MTA data and would like to make a valuable contribution to increasing their overall membership rates.
#
# Our data gives us insight into which stations and days of the week have the most foot-traffic - thus optimizing volunteer placement for outreach. Our analysis even highlights specific turnstiles within a station!
#
# Furthermore, trends by week and time are readily available. Complimentary graphs for viewing pleasure.
#
# Currently, we are in the process of combining census data with our findings to give further insight into the demographics of foot-traffic, that is to say, WTWY's future potential donors and members.

# %%
# imports a library 'pandas', names it as 'pd'
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import pickle

from IPython.display import Image

# enables inline plots, without it plots don't show up in the notebook
# %matplotlib inline

# %%
print("Pandas version:",pd.__version__)
print("Numpy version:",np.__version__)
# Out:
# Pandas version: 0.20.1
# Numpy version: 1.12.1

# %%
# various options in pandas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 200)
pd.set_option('display.precision', 3)

# %% [markdown]
# Download 3 MTA turnstile data files (170513, 170506 and 170429).
# Read the data into a pandas DataFrame.

# %%
MTA_May13 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_170513.txt')
MTA_May06 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_170506.txt')
MTA_Apr29 = pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_170429.txt')

MTAdata = pd.concat([MTA_Apr29, MTA_May06, MTA_May13], ignore_index = True)

MTAdata.rename(columns=lambda x: x.strip(), inplace=True)

# %%
MTAdata.head(10)
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/22/2017  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/22/2017  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/22/2017  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/22/2017  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/22/2017  16:00:00
# 5  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/22/2017  20:00:00
# 6  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/23/2017  00:00:00
# 7  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/23/2017  04:00:00
# 8  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/23/2017  08:00:00
# 9  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/23/2017  12:00:00
#
#       DESC  ENTRIES    EXITS
# 0  REGULAR  6148025  2082120
# 1  REGULAR  6148080  2082123
# 2  REGULAR  6148101  2082157
# 3  REGULAR  6148224  2082251
# 4  REGULAR  6148524  2082316
# 5  REGULAR  6148910  2082368
# 6  REGULAR  6149116  2082395
# 7  REGULAR  6149149  2082398
# 8  REGULAR  6149178  2082419
# 9  REGULAR  6149307  2082504

# %% [markdown]
# Save MTA dataframe locally.

# %%
pickle.dump(MTAdata, open("MTAdata", "wb"))

# %% [markdown]
# Load MTA dataframe.

# %%
MTAdata = pickle.load(open("MTAdata", "rb"))

# %% [markdown]
# The 'DATE' columns are of type object. It prevent us from doing time series analysis.
# Create a new column, 'day' to get the weekday for each result.

# %%
MTAdata['day'] = MTAdata['DATE'].apply(lambda x: pd.to_datetime(x, format = '%m/%d/%Y').weekday())

# %% [markdown]
# C/A      = Control Area (A002)
# UNIT     = Remote Unit for a station (R051)
# SCP      = Subunit Channel Position represents an specific address for a device (02-00-00)
# STATION  = Represents the station name the device is located at
# Create 'turnstile' column, which is defined by 'C/A' and 'SCP'.

# %%
print(MTAdata[['C/A']].drop_duplicates().shape)
print(MTAdata[['UNIT']].drop_duplicates().shape)
print(MTAdata[['SCP']].drop_duplicates().shape)
print(MTAdata[['STATION']].drop_duplicates().shape)
print(MTAdata[['C/A', 'STATION']].drop_duplicates().shape)
print(MTAdata[['C/A', 'STATION', 'UNIT']].drop_duplicates().shape)
print(MTAdata[['STATION', 'UNIT']].drop_duplicates().shape)
print(MTAdata[['STATION', 'UNIT', 'C/A']].drop_duplicates().shape)
print(MTAdata[['STATION', 'UNIT', 'SCP']].drop_duplicates().shape)
print(MTAdata[['STATION', 'SCP']].drop_duplicates().shape)
print(MTAdata[['C/A', 'SCP']].drop_duplicates().shape)
print(MTAdata[['C/A', 'UNIT', 'SCP']].drop_duplicates().shape)
print(MTAdata[['C/A', 'UNIT', 'SCP', 'STATION']].drop_duplicates().shape)
# Out:
# (732, 1)
# (466, 1)
# (230, 1)
# (374, 1)
# (732, 2)
# (732, 3)
# (482, 2)
# (732, 3)
# (4697, 3)
# (4145, 2)
# (4697, 2)
# (4697, 3)
# (4697, 4)

# %%
MTAdata['turnstile'] = MTAdata['C/A'] + ' ' + MTAdata['SCP']

# %%
MTAdata.head(10)
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/22/2017  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/22/2017  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/22/2017  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/22/2017  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/22/2017  16:00:00
# 5  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/22/2017  20:00:00
# 6  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/23/2017  00:00:00
# 7  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/23/2017  04:00:00
# 8  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/23/2017  08:00:00
# 9  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/23/2017  12:00:00
#
#       DESC  ENTRIES    EXITS  day      turnstile
# 0  REGULAR  6148025  2082120    5  A002 02-00-00
# 1  REGULAR  6148080  2082123    5  A002 02-00-00
# 2  REGULAR  6148101  2082157    5  A002 02-00-00
# 3  REGULAR  6148224  2082251    5  A002 02-00-00
# 4  REGULAR  6148524  2082316    5  A002 02-00-00
# 5  REGULAR  6148910  2082368    5  A002 02-00-00
# 6  REGULAR  6149116  2082395    6  A002 02-00-00
# 7  REGULAR  6149149  2082398    6  A002 02-00-00
# 8  REGULAR  6149178  2082419    6  A002 02-00-00
# 9  REGULAR  6149307  2082504    6  A002 02-00-00

# %% [markdown]
# Get the entries and exits for each turnstile.

# %%
MTAdata['turnstile entries'] = MTAdata.groupby(['turnstile'])['ENTRIES'].transform(lambda x: x.diff())
MTAdata['turnstile exits'] = MTAdata.groupby(['turnstile'])['EXITS'].transform(lambda x: x.diff())

# %% [markdown]
# Some of the entry and exit numbers are negative. We assume they are due to the counter errors from the original data.
# The rows with negative entry or exit numbers will be removed.

# %%
MTAdata = MTAdata[(MTAdata['turnstile entries'] > 0) & (MTAdata['turnstile exits'] > 0)]

# %% [markdown]
# Create a column of 'TurnstileDay traffic' which sums up the entries and exits for each turnstile on each weekday.

# %%
MTAdata['turnstile traffic'] = MTAdata['turnstile entries'] + MTAdata['turnstile exits']

# %% [markdown]
# We set up a cutoff of 5000 for each turnstile traffic by assuming that it will take at least 3 sec for one person to get through the turnstile.

# %%
MTAdata = MTAdata[(MTAdata['turnstile traffic'] < 5000)]
MTAdata.head(10)
# Out:
#      C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 1   A002  R051  02-00-00   59 ST  NQR456W      BMT  04/22/2017  04:00:00
# 2   A002  R051  02-00-00   59 ST  NQR456W      BMT  04/22/2017  08:00:00
# 3   A002  R051  02-00-00   59 ST  NQR456W      BMT  04/22/2017  12:00:00
# 4   A002  R051  02-00-00   59 ST  NQR456W      BMT  04/22/2017  16:00:00
# 5   A002  R051  02-00-00   59 ST  NQR456W      BMT  04/22/2017  20:00:00
# 6   A002  R051  02-00-00   59 ST  NQR456W      BMT  04/23/2017  00:00:00
# 7   A002  R051  02-00-00   59 ST  NQR456W      BMT  04/23/2017  04:00:00
# 8   A002  R051  02-00-00   59 ST  NQR456W      BMT  04/23/2017  08:00:00
# 9   A002  R051  02-00-00   59 ST  NQR456W      BMT  04/23/2017  12:00:00
# 10  A002  R051  02-00-00   59 ST  NQR456W      BMT  04/23/2017  16:00:00
#
#        DESC  ENTRIES    EXITS  day      turnstile  turnstile entries  \
# 1   REGULAR  6148080  2082123    5  A002 02-00-00               55.0
# 2   REGULAR  6148101  2082157    5  A002 02-00-00               21.0
# 3   REGULAR  6148224  2082251    5  A002 02-00-00              123.0
# 4   REGULAR  6148524  2082316    5  A002 02-00-00              300.0
# 5   REGULAR  6148910  2082368    5  A002 02-00-00              386.0
# 6   REGULAR  6149116  2082395    6  A002 02-00-00              206.0
# 7   REGULAR  6149149  2082398    6  A002 02-00-00               33.0
# 8   REGULAR  6149178  2082419    6  A002 02-00-00               29.0
# 9   REGULAR  6149307  2082504    6  A002 02-00-00              129.0
# 10  REGULAR  6149514  2082560    6  A002 02-00-00              207.0
#
#     turnstile exits  turnstile traffic
# 1               3.0               58.0
# 2              34.0               55.0
# 3              94.0              217.0
# 4              65.0              365.0
# 5              52.0              438.0
# 6              27.0              233.0
# 7               3.0               36.0
# 8              21.0               50.0
# 9              85.0              214.0
# 10             56.0              263.0

# %% [markdown]
# Get traffic data for each turnstile at each day of the week

# %%
TurnstileDayTotalTraffic = pd.DataFrame(MTAdata.groupby(['C/A','STATION','turnstile','day'])['turnstile traffic'].sum()).reset_index()

# %%
TurnstileDayTotalTraffic.head(10)
# Out:
#     C/A STATION      turnstile  day  turnstile traffic
# 0  A002   59 ST  A002 02-00-00    0             6052.0
# 1  A002   59 ST  A002 02-00-00    1             5972.0
# 2  A002   59 ST  A002 02-00-00    2             6211.0
# 3  A002   59 ST  A002 02-00-00    3             6300.0
# 4  A002   59 ST  A002 02-00-00    4             6328.0
# 5  A002   59 ST  A002 02-00-00    5             3643.0
# 6  A002   59 ST  A002 02-00-00    6             2899.0
# 7  A002   59 ST  A002 02-00-01    0             3304.0
# 8  A002   59 ST  A002 02-00-01    1             3811.0
# 9  A002   59 ST  A002 02-00-01    2             4558.0

# %% [markdown]
# Get total traffic data for each station at each day of the week

# %%
StationDayTotalTraffic = pd.DataFrame(TurnstileDayTotalTraffic.groupby(['STATION','day'])['turnstile traffic'].sum()).reset_index()

# %%
StationDayTotalTraffic.head(10)
# Out:
#   STATION  day  turnstile traffic
# 0    1 AV    0           122304.0
# 1    1 AV    1           137411.0
# 2    1 AV    2           140604.0
# 3    1 AV    3           142805.0
# 4    1 AV    4           145416.0
# 5    1 AV    5            78426.0
# 6    1 AV    6            65153.0
# 7  103 ST    0           156227.0
# 8  103 ST    1           165289.0
# 9  103 ST    2           169931.0

# %% [markdown]
# Get the average traffic data for each day of the week.

# %%
DayTotalTraffic = pd.DataFrame(StationDayTotalTraffic.groupby(['day'])['turnstile traffic'].sum()).reset_index()
DayAverageTraffic = DayTotalTraffic
DayAverageTraffic['turnstile traffic'] = DayAverageTraffic['turnstile traffic'] / 3
DayAverageTraffic.sort_values('day')
# Out:
#    day  turnstile traffic
# 0    0          9.976e+06
# 1    1          1.055e+07
# 2    2          1.069e+07
# 3    3          1.082e+07
# 4    4          1.041e+07
# 5    5          6.053e+06
# 6    6          5.128e+06

# %%
fig, ax = plt.subplots()
fig.set_size_inches(8,8)
sns.barplot(x = DayAverageTraffic['day'], y = DayAverageTraffic['turnstile traffic']);

# %%
plt.figure(figsize=(10,6))
plt.plot(DayAverageTraffic['day'],DayAverageTraffic['turnstile traffic'])
plt.xlabel('weekday')
plt.ylabel('total traffic');

# %%
StationWeekdayTotalTraffic = pd.DataFrame(StationDayTotalTraffic[StationDayTotalTraffic['day'] < 5].groupby(['STATION'])['turnstile traffic'].sum()).reset_index()
StationWeekdayAverageTraffic = StationWeekdayTotalTraffic
StationWeekdayAverageTraffic['turnstile traffic'] = StationWeekdayAverageTraffic['turnstile traffic']/15
StationWeekdayAverageTraffic.sort_values('turnstile traffic',ascending = False)
# Out:
#              STATION  turnstile traffic
# 61    34 ST-PENN STA         312259.800
# 232  GRD CNTRL-42 ST         283873.867
# 59   34 ST-HERALD SQ         227598.733
# 46             23 ST         216605.400
# 14    14 ST-UNION SQ         200417.333
# 349   TIMES SQ-42 ST         188466.133
# 225        FULTON ST         182730.800
# 109            86 ST         163220.800
# 68   42 ST-PORT AUTH         161554.000
# 85    59 ST COLUMBUS         139153.333
# 9             125 ST         134918.400
# 84             59 ST         133792.333
# 172         CANAL ST         125915.600
# 72    47-50 STS ROCK         122976.000
# 179      CHAMBERS ST         121866.467
# 114            96 ST         120910.933
# 13             14 ST         110966.733
# 312     PATH NEW WTC         108977.133
# 216    FLUSHING-MAIN         107771.133
# 52             28 ST          99937.667
# 361          WALL ST          91931.800
# 78             50 ST          91627.533
# 256  JKSN HT-ROOSVLT          89020.067
# 268  LEXINGTON AV/53          88569.667
# 96             72 ST          85860.067
# 67   42 ST-BRYANT PK          85747.933
# 358   W 4 ST-WASH SQ          83765.067
# 124   ATL AV-BARCLAY          82714.667
# 94              7 AV          77969.467
# 253  JAY ST-METROTEC          75305.333
# 15            145 ST          72297.267
# 251   JAMAICA CENTER          71697.600
# 101            77 ST          66779.267
# 182        CHURCH AV          66186.467
# 103             8 AV          64465.133
# 155     BOROUGH HALL          64461.467
# 158    BOWLING GREEN          60399.067
# 148       BEDFORD AV          58774.000
# 259      KEW GARDENS          57336.667
# 195  CROWN HTS-UTICA          55668.667
# 1             103 ST          55258.067
# 75        5 AV/53 ST          55028.333
# 57             33 ST          54834.600
# 97       72 ST-2 AVE          54791.867
# 6             116 ST          53628.533
# 229         GRAND ST          53009.667
# 260        KINGS HWY          52968.067
# 134  B'WAY-LAFAYETTE          52012.467
# 73             49 ST          48627.800
# 257   JOURNAL SQUARE          48071.867
# 92    68ST-HUNTER CO          47726.267
# 90     66 ST-LINCOLN          47078.733
# 83        57 ST-7 AV          47037.200
# 199   DELANCEY/ESSEX          46907.533
# 33            181 ST          46032.467
# 0               1 AV          45902.667
# 79             51 ST          45696.200
# 24            168 ST          44705.933
# 219  FOREST HILLS 71          44466.400
# 345   SUTPHIN-ARCHER          44452.600
# 198        DEKALB AV          43711.933
# 110      86 ST-2 AVE          42679.000
# 234     GROVE STREET          42075.200
# 368   WOODHAVEN BLVD          41948.533
# 21   161/YANKEE STAD          41891.800
# 258    JUNCTION BLVD          41402.000
# 314  PAVONIA/NEWPORT          40509.733
# 269  LEXINGTON AV/63          40290.267
# 305      NOSTRAND AV          40074.533
# 167  BROOKLYN BRIDGE          38574.800
# 339        SPRING ST          38424.333
# 348  THIRTY THIRD ST          37954.667
# 136         BAY PKWY          36530.533
# 364  WHITEHALL S-FRY          36200.333
# 183       CITY / BUS          36123.133
# 87    61 ST WOODSIDE          36075.467
# 212   EXCHANGE PLACE          35601.667
# 2      103 ST-CORONA          35288.400
# 121         ASTOR PL          35063.067
# 309      PARKCHESTER          35043.600
# 23            167 ST          34885.267
# 107  82 ST-JACKSON H          34404.867
# 38              2 AV          33914.200
# 287   MYRTLE-WYCKOFF          33691.733
# 123  ASTORIA DITMARS          32871.733
# 102            79 ST          32745.133
# 217       FORDHAM RD          32648.867
# 250   JAMAICA 179 ST          32543.600
# 191     CORTLANDT ST          32387.667
# 176   CATHEDRAL PKWY          32369.267
# 220      FRANKLIN AV          32166.333
# 214  FLATBUSH AV-B.C          32123.067
# 63             36 ST          32039.600
# 10            135 ST          31468.800
# 55       3 AV-149 ST          31223.733
# 115      96 ST-2 AVE          31210.800
# 261   KINGSBRIDGE RD          31029.867
# 163         BROADWAY          30693.000
# 338      SOUTH FERRY          30359.600
# 353         UTICA AV          30333.467
# ..               ...                ...
# 237    HARLEM 148 ST           8081.667
# 205      EAST 105 ST           8069.733
# 118      ALLERTON AV           7990.667
# 50             25 AV           7946.800
# 344     SUTPHIN BLVD           7814.933
# 39             20 AV           7808.000
# 98    74 ST-BROADWAY           7779.800
# 28       174-175 STS           7720.133
# 95             71 ST           7661.400
# 218       FOREST AVE           7644.400
# 168         BUHRE AV           7505.333
# 249       JACKSON AV           7495.867
# 242   HOWARD BCH JFK           7429.333
# 177       CENTRAL AV           7411.733
# 265    KOSCIUSZKO ST           7331.133
# 105            80 ST           7270.267
# 366        WILSON AV           7229.733
# 274  MARBLE HILL-225           7209.200
# 34       182-183 STS           7190.533
# 304       NORWOOD AV           7107.533
# 247     INTERVALE AV           7094.067
# 48            233 ST           7060.067
# 272      LONGWOOD AV           7027.133
# 36            190 ST           6984.000
# 267     LAFAYETTE AV           6977.867
# 51             25 ST           6853.000
# 196       CYPRESS AV           6835.467
# 187     CLEVELAND ST           6835.333
# 45            225 ST           6783.600
# 12    138/GRAND CONC           6720.933
# 356   VAN SICLEN AVE           6596.400
# 317  PENNSYLVANIA AV           6569.600
# 126         AVENUE H           6510.533
# 200        DITMAS AV           6454.533
# 100    75 ST-ELDERTS           6427.467
# 152    BEVERLEY ROAD           6347.333
# 89             65 ST           6331.067
# 157           BOWERY           6275.533
# 108  85 ST-FOREST PK           6123.000
# 297         NEWARK C           5888.267
# 86              6 AV           5833.667
# 271       LIVONIA AV           5773.667
# 289          NECK RD           5708.600
# 299  NEWARK HW BMEBE           5680.267
# 333       SENECA AVE           5562.467
# 44            219 ST           5424.867
# 372        ZEREGA AV           5398.400
# 335      SHEPHERD AV           5365.467
# 153       BEVERLY RD           5314.333
# 291        NEREID AV           5292.600
# 282      MORRIS PARK           5292.600
# 306       OCEAN PKWY           5252.933
# 117       ALABAMA AV           5126.533
# 64             39 AV           5065.467
# 169         BURKE AV           4961.267
# 130         AVENUE N           4874.867
# 180      CHAUNCEY ST           4867.933
# 139    BAYCHESTER AV           4850.800
# 49            238 ST           4819.333
# 270       LIBERTY AV           4594.533
# 278    MIDDLETOWN RD           4509.533
# 145      BEACH 67 ST           4488.000
# 239         HEWES ST           4414.133
# 144      BEACH 60 ST           4363.533
# 22   163 ST-AMSTERDM           4306.400
# 111            88 ST           4285.333
# 156   BOTANIC GARDEN           4192.933
# 165  BRONX PARK EAST           4098.867
# 99             75 AV           4090.400
# 365      WHITLOCK AV           4088.400
# 131         AVENUE P           4079.000
# 135        BAY 50 ST           3961.467
# 137     BAY RIDGE AV           3921.267
# 41             21 ST           3862.667
# 3             104 ST           3821.133
# 359  W 8 ST-AQUARIUM           3709.000
# 171      BUSHWICK AV           3663.533
# 141      BEACH 25 ST           3629.067
# 133         AVENUE X           3411.600
# 327    RIT-ROOSEVELT           3258.800
# 326    RIT-MANHATTAN           3211.000
# 81             55 ST           3173.867
# 43            215 ST           2980.267
# 119  AQUEDUCT N.COND           2880.667
# 125      ATLANTIC AV           2750.733
# 290       NEPTUNE AV           2643.333
# 197    CYPRESS HILLS           2555.400
# 202  E 143/ST MARY'S           2190.267
# 142      BEACH 36 ST           2141.733
# 120  AQUEDUCT RACETR           1855.467
# 127         AVENUE I           1726.600
# 143      BEACH 44 ST           1566.733
# 146      BEACH 90 ST           1560.267
# 330  ROCKAWAY PARK B           1491.400
# 8             121 ST           1094.533
# 147      BEACH 98 ST           1043.333
# 140     BEACH 105 ST            593.200
# 298     NEWARK HM HE            490.600
# 161    BROAD CHANNEL            331.067
# 341       ST. GEORGE            149.467
#
# [373 rows x 2 columns]

# %%
AverageDailyTraffic = DayAverageTraffic['turnstile traffic'].sum()/7
AverageDailyTraffic
# Out:
# 9090372.904761905

# %%
TimesSq42St = pd.DataFrame(MTAdata[MTAdata['STATION'] == 'TIMES SQ-42 ST'].groupby(['turnstile'])['turnstile traffic'].sum()).reset_index()
TimesSq42St
# Out:
#         turnstile  turnstile traffic
# 0   A021 01-00-00           142746.0
# 1   A021 01-00-01            91882.0
# 2   A021 01-00-02            59459.0
# 3   A021 01-00-03            37677.0
# 4   A021 01-00-04            48900.0
# 5   A021 01-00-05            64676.0
# 6   A021 01-00-06            80591.0
# 7   A021 01-00-07           108463.0
# 8   R143 02-00-00            94011.0
# 9   R143 02-00-01            69805.0
# 10  R143 02-00-02            54290.0
# 11  R143 02-00-03            46999.0
# 12  R143 02-03-00            55324.0
# 13  R143 02-03-01            53670.0
# 14  R143 02-03-02            63077.0
# 15  R143 02-03-03            83151.0
# 16  R145 00-00-00            75431.0
# 17  R145 00-00-01            42541.0
# 18  R145 00-00-02            33391.0
# 19  R145 00-00-03            28564.0
# 20  R145 00-00-04            14801.0
# 21  R145 00-06-00            88692.0
# 22  R145 00-06-01           115050.0
# 23  R145 00-06-02           104185.0
# 24  R147 04-00-00            77706.0
# 25  R147 04-00-01            75232.0
# 26  R147 04-00-02            81165.0
# 27  R147 04-00-03            86099.0
# 28  R147 04-00-04            82043.0
# 29  R147 04-00-05            72678.0
# 30  R147 04-00-06            68529.0
# 31  R148 01-00-00           133187.0
# 32  R148 01-03-00            15135.0
# 33  R148 01-03-01            23243.0
# 34  R148 01-03-02            26970.0
# 35  R148 01-03-03            21722.0
# 36  R148 01-06-00            89546.0
# 37  R148 01-06-01            61886.0
# 38  R151 00-00-00            50026.0
# 39  R151 00-00-01           128851.0
# 40  R151 00-00-02           122664.0
# 41  R151 00-00-03           131547.0
# 42  R151 00-00-04           129340.0
# 43  R151 00-00-05           120510.0
# 44  R151 00-00-06           110971.0
# 45  R151 00-00-07            80806.0
# 46  R151 00-00-08            91684.0

# %%
fig, ax = plt.subplots()
fig.set_size_inches(8,8)
sns.barplot(x = TimesSq42St['turnstile traffic'], y = TimesSq42St['turnstile'])
